# %% [markdown]
# <a href="https://colab.research.google.com/github/vacuiiity/Vroberts_coding_final/blob/main/Hello_kitty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ColabTurtlePlus
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ColabTurtlePlus
#   Downloading ColabTurtlePlus-2.0.1-py3-none-any.whl (31 kB)
# Installing collected packages: ColabTurtlePlus
# Successfully installed ColabTurtlePlus-2.0.1

# %%
from ColabTurtlePlus.Turtle import *
clearscreen()
setup(800,800)
bgcolor(50,20,90)
black = Turtle()
black.color((0,0,0))
white = Turtle()
white.color((220,220,220))
red = Turtle()
red.color((220,0,0))
face = Turtle()
face.color((0,0,0))
# Out:
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell
#       <svg width="800" height="800">
#         <rect width="100%" height="100%" style="fill:rgb(50,20,90);stroke:;stroke-width:1"/>
#
#
#
#
#
#         <g id="classic" visibility="visible" transform="rotate(-90,400.0,400.0) translate(400.0, 400.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:rgb(0,0,0);fill:rgb(0,0,0);stroke-width:1" />
# </g><g id="classic" visibility="visible" transform="rotate(-90,400.0,400.0) translate(400.0, 400.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:rgb(220,220,220);fill:rgb(220,220,220);stroke-width:1" />
# </g><g id="classic" visibility="visible" transform="rotate(-90,400.0,400.0) translate(400.0, 400.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:rgb(220,0,0);fill:rgb(220,0,0);stroke-width:1" />
# </g><g id="classic" visibility="visible" transform="rotate(-90,400.0,400.0) translate(400.0, 400.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:rgb(0,0,0);fill:rgb(0,0,0);stroke-width:1" />
# </g>
#       </svg>

# %%
def draw_square(turtle_obj, side_length):
  for i in range(4):
    turtle_obj.forward(side_length)
    turtle_obj.left(90)

# %%
black_telem_list = []
red_telem_list = []
white_telem_list = []
face_telem_list = []

black.jumpto(-145,-140)
black_telem_list.append((black.xcor(), black.ycor()))
black.begin_fill()
draw_square(black,335)
black_telem_list.append((black.xcor(), black.ycor()))
black.end_fill()


black.jumpto(-180,-120)
black_telem_list.append((black.xcor(), black.ycor()))
black.begin_fill()
draw_square(black,300)
black_telem_list.append((black.xcor(), black.ycor()))
black.end_fill()


black.jumpto(-200,-70)
black_telem_list.append((black.xcor(), black.ycor()))
black.begin_fill()
draw_square(black,250)
black_telem_list.append((black.xcor(), black.ycor()))
black.end_fill()

black.jumpto(-60,-120)
black_telem_list.append((black.xcor(), black.ycor()))
black.begin_fill()
draw_square(black,300)
black_telem_list.append((black.xcor(), black.ycor()))
black.end_fill()

black.jumpto(10,-70)
black_telem_list.append((black.xcor(), black.ycor()))
black.begin_fill()
draw_square(black,250)
black_telem_list.append((black.xcor(), black.ycor()))
black.end_fill()

black.jumpto(-155,130)
black_telem_list.append((black.xcor(), black.ycor()))
black.begin_fill()
draw_square(black,100)
black_telem_list.append((black.xcor(), black.ycor()))
black.end_fill()

black.jumpto(-140,190)
black_telem_list.append((black.xcor(), black.ycor()))
black.begin_fill()
draw_square(black,75)
black_telem_list.append((black.xcor(), black.ycor()))
black.end_fill()

black.jumpto(100,130)
black_telem_list.append((black.xcor(), black.ycor()))
black.begin_fill()
draw_square(black,120)
black_telem_list.append((black.xcor(), black.ycor()))
black.end_fill()

black.jumpto(115,190)
black_telem_list.append((black.xcor(), black.ycor()))
black.begin_fill()
draw_square(black,75)
black_telem_list.append((black.xcor(), black.ycor()))
black.end_fill()

black.jumpto(50,110)
black_telem_list.append((black.xcor(), black.ycor()))
black.begin_fill()
draw_square(black,140)
black_telem_list.append((black.xcor(), black.ycor()))
black.end_fill()

black.jumpto(140,40)
black_telem_list.append((black.xcor(), black.ycor()))
black.begin_fill()
draw_square(black,140)
black_telem_list.append((black.xcor(), black.ycor()))
black.end_fill()


white.jumpto(-120,-120)
white_telem_list.append((white.xcor(), white.ycor()))
white.begin_fill()
draw_square(white,300)
white_telem_list.append((white.xcor(), white.ycor()))
white.end_fill()

white.jumpto(-160,-100)
white_telem_list.append((white.xcor(), white.ycor()))
white.begin_fill()
draw_square(white,260)
white_telem_list.append((white.xcor(), white.ycor()))
white.end_fill()

white.jumpto(-180,-80)
white_telem_list.append((white.xcor(), white.ycor()))
white.begin_fill()
draw_square(white,220)
white_telem_list.append((white.xcor(), white.ycor()))
white.end_fill()

white.jumpto(-40,-100)
white_telem_list.append((white.xcor(), white.ycor()))
white.begin_fill()
draw_square(white,260)
white_telem_list.append((white.xcor(), white.ycor()))
white.end_fill()

white.jumpto(20,-80)
white_telem_list.append((white.xcor(), white.ycor()))
white.begin_fill()
draw_square(white,220)
white_telem_list.append((white.xcor(), white.ycor()))
white.end_fill()

white.jumpto(-140,140)
white_telem_list.append((white.xcor(), white.ycor()))
white.begin_fill()
draw_square(white,80)
white_telem_list.append((white.xcor(), white.ycor()))
white.end_fill()

white.jumpto(-125,210)
white_telem_list.append((white.xcor(), white.ycor()))
white.begin_fill()
draw_square(white,40)
white_telem_list.append((white.xcor(), white.ycor()))
white.end_fill()

white.jumpto(120,140)
white_telem_list.append((white.xcor(), white.ycor()))
white.begin_fill()
draw_square(white,80)
white_telem_list.append((white.xcor(), white.ycor()))
white.end_fill()

white.jumpto(135,210)
white_telem_list.append((white.xcor(), white.ycor()))
white.begin_fill()
draw_square(white,40)
white_telem_list.append((white.xcor(), white.ycor()))
white.end_fill()

red.jumpto(70,140)
red_telem_list.append((red.xcor(), red.ycor()))
red.begin_fill()
draw_square(red,100)
red_telem_list.append((red.xcor(), red.ycor()))
red.end_fill()

red.jumpto(120,100)
red_telem_list.append((red.xcor(), red.ycor()))
red.begin_fill()
draw_square(red,40)
red_telem_list.append((red.xcor(), red.ycor()))
red.end_fill()

red.jumpto(160,60)
red_telem_list.append((red.xcor(), red.ycor()))
red.begin_fill()
draw_square(red,100)
red_telem_list.append((red.xcor(), red.ycor()))
red.end_fill()

face.jumpto(-10,-30)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(10,-30)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-80,30)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-80,10)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(80,30)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(80,10)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(120,140)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(140,160)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(160,100)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(180,120)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-160,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-180,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-200,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-220,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-160,-20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-180,-20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-200,-20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-220,-20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-160,-60)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-180,-60)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-200,-60)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(-220,-60)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(200,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(220,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(240,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(260,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(200,-20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(220,-20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(240,-20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(260,-20)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(200,-60)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(220,-60)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(240,-60)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()

face.jumpto(260,-60)
face_telem_list.append((face.xcor(), face.ycor()))
face.begin_fill()
draw_square(face,20)
face_telem_list.append((face.xcor(), face.ycor()))
face.end_fill()
# Out:
#       <svg width="800" height="800">
#         <rect width="100%" height="100%" style="fill:rgb(50,20,90);stroke:;stroke-width:1"/>
#
#
#         <path fill-rule="evenodd" fill-opacity="1" d="M 255.0 540.0  L 590.0 540.0  L 590.0 205.0  L 255.0 205.0  L 255.0 540.0 " stroke-linecap="round" style="stroke:rgb(0,0,0);stroke-width:1" fill="rgb(0,0,0)" /><path fill-rule="evenodd" fill-opacity="1" d="M 220.0 520.0  L 520.0 520.0  L 520.0 220.0  L 220.0 220.0  L 220.0 520.0 " stroke-linecap="round" style="stroke:rgb(0,0,0);stroke-width:1" fill="rgb(0,0,0)" /><path fill-rule="evenodd" fill-opacity="1" d="M 200.0 470.0  L 450.0 470.0  L 450.0 220.0  L 200.0 220.0  L 200.0 470.0 " stroke-linecap="round" style="stroke:rgb(0,0,0);stroke-width:1" fill="rgb(0,0,0)" /><path fill-rule="evenodd" fill-opacity="1" d="M 340.0 520.0  L 640.0 520.0  L 640.0 220.0  L 340.0 220.0  L 340.0 520.0 " stroke-linecap="round" style="stroke:rgb(0,0,0);stroke-width:1" fill="rgb(0,0,0)" /><path fill-rule="evenodd" fill-opacity="1" d="M 410.0 470.0  L 660.0 470.0  L 660.0 220.0  L 410.0 220.0  L 410.0 470.0 " stroke-linecap="round" style="stroke:rgb(0,0,0);stroke-width:1" fill="rgb(0,0,0)" /><path fill-rule="evenodd" fill-opacity="1" d="M 245.0 270.0  L 345.0 270.0  L 345.0 170.0  L 245.0 170.0  L 245.0 270.0 " stroke-linecap="round" style="stroke:rgb(0,0,0);stroke-width:1" fill="rgb(0,0,0)" /><path fill-rule="evenodd" fill-opacity="1" d="M 260.0 210.0  L 335.0 210.0  L 335.0 135.0  L 260.0 135.0  L 260.0 210.0 " stroke-linecap="round" style="stroke:rgb(0,0,0);stroke-width:1" fill="rgb(0,0,0)" /><path fill-rule="evenodd" fill-opacity="1" d="M 500.0 270.0  L 620.0 270.0  L 620.0 150.0  L 500.0 150.0  L 500.0 270.0 " stroke-linecap="round" style="stroke:rgb(0,0,0);stroke-width:1" fill="rgb(0,0,0)" /><path fill-rule="evenodd" fill-opacity="1" d="M 515.0 210.0  L 590.0 210.0  L 590.0 135.0  L 515.0 135.0  L 515.0 210.0 " stroke-linecap="round" style="stroke:rgb(0,0,0);stroke-width:1" fill="rgb(0,0,0)" /><path fill-rule="evenodd" fill-opacity="1" d="M 450.0 290.0  L 590.0 290.0  L 590.0 150.0  L 450.0 150.0  L 450.0 290.0 " stroke-linecap="round" style="stroke:rgb(0,0,0);stroke-width:1" fill="rgb(0,0,0)" /><path fill-rule="evenodd" fill-opacity="1" d="M 540.0 360.0  L 680.0 360.0  L 680.0 220.0  L 540.0 220.0  L 540.0 360.0 " stroke-linecap="round" style="stroke:rgb(0,0,0);stroke-width:1" fill="rgb(0,0,0)" /><path fill-rule="evenodd" fill-opacity="1" d="M 280.0 520.0  L 580.0 520.0  L 580.0 220.0  L 280.0 220.0  L 280.0 520.0 " stroke-linecap="round" style="stroke:rgb(220,220,220);stroke-width:1" fill="rgb(220,220,220)" /><path fill-rule="evenodd" fill-opacity="1" d="M 240.0 500.0  L 500.0 500.0  L 500.0 240.0  L 240.0 240.0  L 240.0 500.0 " stroke-linecap="round" style="stroke:rgb(220,220,220);stroke-width:1" fill="rgb(220,220,220)" /><path fill-rule="evenodd" fill-opacity="1" d="M 220.0 480.0  L 440.0 480.0  L 440.0 260.0  L 220.0 260.0  L 220.0 480.0 " stroke-linecap="round" style="stroke:rgb(220,220,220);stroke-width:1" fill="rgb(220,220,220)" /><path fill-rule="evenodd" fill-opacity="1" d="M 360.0 500.0  L 620.0 500.0  L 620.0 240.0  L 360.0 240.0  L 360.0 500.0 " stroke-linecap="round" style="stroke:rgb(220,220,220);stroke-width:1" fill="rgb(220,220,220)" /><path fill-rule="evenodd" fill-opacity="1" d="M 420.0 480.0  L 640.0 480.0  L 640.0 260.0  L 420.0 260.0  L 420.0 480.0 " stroke-linecap="round" style="stroke:rgb(220,220,220);stroke-width:1" fill="rgb(220,220,220)" /><path fill-rule="evenodd" fill-opacity="1" d="M 260.0 260.0  L 340.0 260.0  L 340.0 180.0  L 260.0 180.0  L 260.0 260.0 " stroke-linecap="round" style="stroke:rgb(220,220,220);stroke-width:1" fill="rgb(220,220,220)" /><path fill-rule="evenodd" fill-opacity="1" d="M 275.0 190.0  L 315.0 190.0  L 315.0 150.0  L 275.0 150.0  L 275.0 190.0 " stroke-linecap="round" style="stroke:rgb(220,220,220);stroke-width:1" fill="rgb(220,220,220)" /><path fill-rule="evenodd" fill-opacity="1" d="M 520.0 260.0  L 600.0 260.0  L 600.0 180.0  L 520.0 180.0  L 520.0 260.0 " stroke-linecap="round" style="stroke:rgb(220,220,220);stroke-width:1" fill="rg ...

# %%
draw_dict = {
    'turtle_1': black,
    'turtle_2': red,
    'turtle_3': white,
    'turtle_4': face
}

# %%
for turtle, telem_dict in draw_dict.items(): 
  print(turtle)
for category, data in draw_dict.items():
    print(f'category: {category} | data: {data}')
# Out:
# turtle_1
# turtle_2
# turtle_3
# turtle_4
# category: turtle_1 | data: <ColabTurtlePlus.Turtle.Turtle object at 0x7fedd7f62d30>
# category: turtle_2 | data: <ColabTurtlePlus.Turtle.Turtle object at 0x7fedd7f62a00>
# category: turtle_3 | data: <ColabTurtlePlus.Turtle.Turtle object at 0x7fedd66c4880>
# category: turtle_4 | data: <ColabTurtlePlus.Turtle.Turtle object at 0x7fedd7f623d0>

# %%
draw_dict = {
    'turtle_black' : black_telem_list,
    'turtle_red' : red_telem_list,
    'turtle_white' : white_telem_list,
    'turtle_face' : face_telem_list
}

for turtle, data in draw_dict.items():
  print(f'turtle_name: {turtle} | data: {data}')
# Out:
# turtle_name: turtle_black | data: [(-145.0, -140.0), (-145.0, -140.0), (-180.0, -120.0), (-180.0, -120.0), (-200.0, -70.0), (-200.0, -70.0), (-60.0, -120.0), (-60.0, -120.0), (10.0, -70.0), (10.0, -70.0), (-155.0, 130.0), (-155.0, 130.0), (-140.0, 190.0), (-140.0, 190.0), (100.0, 130.0), (100.0, 130.0), (115.0, 190.0), (115.0, 190.0), (50.0, 110.0), (50.0, 110.0), (140.0, 40.0), (140.0, 40.0)]
# turtle_name: turtle_red | data: [(70.0, 140.0), (70.0, 140.0), (120.0, 100.0), (120.0, 100.0), (160.0, 60.0), (160.0, 60.0)]
# turtle_name: turtle_white | data: [(-120.0, -120.0), (-120.0, -120.0), (-160.0, -100.0), (-160.0, -100.0), (-180.0, -80.0), (-180.0, -80.0), (-40.0, -100.0), (-40.0, -100.0), (20.0, -80.0), (20.0, -80.0), (-140.0, 140.0), (-140.0, 140.0), (-125.0, 210.0), (-125.0, 210.0), (120.0, 140.0), (120.0, 140.0), (135.0, 210.0), (135.0, 210.0)]
# turtle_name: turtle_face | data: [(-10.0, -30.0), (-10.0, -30.0), (10.0, -30.0), (10.0, -30.0), (-80.0, 30.0), (-80.0, 30.0), (-80.0, 10.0), (-80.0, 10.0), (80.0, 30.0), (80.0, 30.0), (80.0, 10.0), (80.0, 10.0), (120.0, 140.0), (120.0, 140.0), (140.0, 160.0), (140.0, 160.0), (160.0, 100.0), (160.0, 100.0), (180.0, 120.0), (180.0, 120.0), (-160.0, 20.0), (-160.0, 20.0), (-180.0, 20.0), (-180.0, 20.0), (-200.0, 20.0), (-200.0, 20.0), (-220.0, 20.0), (-220.0, 20.0), (-160.0, -20.0), (-160.0, -20.0), (-180.0, -20.0), (-180.0, -20.0), (-200.0, -20.0), (-200.0, -20.0), (-220.0, -20.0), (-220.0, -20.0), (-160.0, -60.0), (-160.0, -60.0), (-180.0, -60.0), (-180.0, -60.0), (-200.0, -60.0), (-200.0, -60.0), (-220.0, -60.0), (-220.0, -60.0), (200.0, 20.0), (200.0, 20.0), (220.0, 20.0), (220.0, 20.0), (240.0, 20.0), (240.0, 20.0), (260.0, 20.0), (260.0, 20.0), (200.0, -20.0), (200.0, -20.0), (220.0, -20.0), (220.0, -20.0), (240.0, -20.0), (240.0, -20.0), (260.0, -20.0), (260.0, -20.0), (200.0, -60.0), (200.0, -60.0), (220.0, -60.0), (220.0, -60.0), (240.0, -60.0), (240.0, -60.0), (260.0, -60.0), (260.0, -60.0)]

# %%
import json
with open("Turtle_Drawing_hellokitty.json", 'w') as json_obj:
  json.dump(draw_dict, json_obj, indent=2)
print('file written')
# Out:
# file written

# %%
screen_obj = Screen()
screen_obj.saveSVG('hellokitty.svg', False)
print('file written')
# Out:
# file written
